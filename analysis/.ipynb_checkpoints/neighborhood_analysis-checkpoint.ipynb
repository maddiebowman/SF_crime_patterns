# %%
# Import dependecies
import pandas as pd
import os
import csv
import matplotlib.pyplot as plt

# %%
# Read in data
csv_path = os.path.join("../data/Police_Department_Incident_Reports.csv")
crime_df = pd.read_csv(csv_path)

# Show first 10 rows of DataFrame
crime_df.head(10)
# Out:
#         Incident Datetime Incident Date Incident Time  Incident Year  \
# 0  2023/03/13 11:41:00 PM    2023/03/13         23:41           2023
# 1  2023/03/01 05:02:00 AM    2023/03/01         05:02           2023
# 2  2023/03/13 01:16:00 PM    2023/03/13         13:16           2023
# 3  2023/03/13 10:59:00 AM    2023/03/13         10:59           2023
# 4  2023/03/14 06:44:00 PM    2023/03/14         18:44           2023
# 5  2023/02/15 03:00:00 AM    2023/02/15         03:00           2023
# 6  2023/03/11 12:30:00 PM    2023/03/11         12:30           2023
# 7  2023/03/13 11:26:00 AM    2023/03/13         11:26           2023
# 8  2023/03/11 03:00:00 PM    2023/03/11         15:00           2023
# 9  2023/03/11 02:00:00 PM    2023/03/11         14:00           2023
#
#   Incident Day of Week         Report Datetime        Row ID  Incident ID  \
# 0               Monday  2023/03/13 11:41:00 PM  125373607041      1253736
# 1            Wednesday  2023/03/11 03:40:00 PM  125379506374      1253795
# 2               Monday  2023/03/13 01:17:00 PM  125357107041      1253571
# 3               Monday  2023/03/13 11:00:00 AM  125355107041      1253551
# 4              Tuesday  2023/03/14 06:45:00 PM  125402407041      1254024
# 5            Wednesday  2023/03/11 04:55:00 PM  125378606372      1253786
# 6             Saturday  2023/03/12 04:15:00 PM  125381606244      1253816
# 7               Monday  2023/03/13 01:37:00 PM  125419506244      1254195
# 8             Saturday  2023/03/13 08:29:00 AM  125420606244      1254206
# 9             Saturday  2023/03/15 11:21:00 AM  125431804134      1254318
#
#    Incident Number   CAD Number  ...   Longitude  \
# 0        230167874          NaN  ...         NaN
# 1        236046151          NaN  ...         NaN
# 2        220343896          NaN  ...         NaN
# 3        230174885          NaN  ...         NaN
# 4        230176728          NaN  ...         NaN
# 5        236046123          NaN  ...         NaN
# 6        236046004          NaN  ...         NaN
# 7        236046850          NaN  ...         NaN
# 8        236045937          NaN  ...         NaN
# 9        230182844  230741133.0  ... -122.454285
#
#                                             Point Neighborhoods  \
# 0                                             NaN           NaN
# 1                                             NaN           NaN
# 2                                             NaN           NaN
# 3                                             NaN           NaN
# 4                                             NaN           NaN
# 5                                             NaN           NaN
# 6                                             NaN           NaN
# 7                                             NaN           NaN
# 8                                             NaN           NaN
# 9  POINT (-122.45428511766733 37.772895177200766)           NaN
#
#    ESNCAG - Boundary File  \
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# 5                     NaN
# 6                     NaN
# 7                     NaN
# 8                     NaN
# 9                     NaN
#
#   Central Market/Tenderloin Boundary Polygon - Updated  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#   Civic Center Harm Reduction Project Boundary HSOC Zones as of 2018-06-05  \
# 0                                          NaN                         NaN
# 1                                          NaN                         NaN
# 2                                          NaN                         NaN
# 3                                          NaN                         NaN
# 4                                          NaN                         NaN
# 5                                          NaN                         NaN
# 6                                          NaN                         NaN
# 7                                          NaN                         NaN
# 8                                          NaN                         NaN
# 9                                          NaN                         NaN
#
#   Invest In Neighborhoods (IIN) Areas Current Supervisor Districts  \
# 0                                 NaN                          NaN
# 1                                 NaN                          NaN
# 2                                 NaN                          NaN
# 3                                 NaN                          NaN
# 4                                 NaN                          NaN
# 5                                 NaN                          NaN
# 6                                 NaN                          NaN
# 7                                 NaN                          NaN
# 8                                 NaN                          NaN
# 9                                 NaN                          4.0
#
#    Current Police Districts
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# 5                       NaN
# 6                       NaN
# 7                       NaN
# 8                       NaN
# 9                       7.0
#
# [10 rows x 35 columns]

# %%
# Check that data was successfully imported by counting rows
num_rows = len(crime_df)
print("Number of rows in the DataFrame:", num_rows)
# Out:
# Number of rows in the DataFrame: 850895

# %%
# Determine datatypes for each column
print(crime_df.dtypes)
# Out:
# Incident Datetime                                        object
# Incident Date                                            object
# Incident Time                                            object
# Incident Year                                             int64
# Incident Day of Week                                     object
# Report Datetime                                          object
# Row ID                                                    int64
# Incident ID                                               int64
# Incident Number                                           int64
# CAD Number                                              float64
# Report Type Code                                         object
# Report Type Description                                  object
# Filed Online                                             object
# Incident Code                                             int64
# Incident Category                                        object
# Incident Subcategory                                     object
# Incident Description                                     object
# Resolution                                               object
# Intersection                                             object
# CNN                                                     float64
# Police District                                          object
# Analysis Neighborhood                                    object
# Supervisor District                                     float64
# Supervisor District 2012                                float64
# Latitude                                                float64
# Longitude                                               float64
# Point                                                    object
# Neighborhoods                                           float64
# ESNCAG - Boundary File                                  float64
# Central Market/Tenderloin Boundary Polygon - Updated    float64
# Civic Center Harm Reduction Project Boundary            float64
# HSOC Zones as of 2018-06-05                             float64
# Invest In Neighborhoods (IIN) Areas                     float64
# Current Supervisor Districts                            float64
# Current Police Districts                                float64
# dtype: object

# %%
# Drop unwanted columns and corss-reference to original DataFrame
print("Original DataFrame:")
print("-------------------")
print(crime_df.dtypes)

columns_to_drop = ['Row ID',
                   'Report Type Code',
                   'Report Type Description',
                   'CAD Number',
                   'Filed Online',
                   'CNN',
                   'Supervisor District',
                   'Supervisor District 2012',
                   'Neighborhoods',
                   'ESNCAG - Boundary File',
                   'Central Market/Tenderloin Boundary Polygon - Updated',
                   'Civic Center Harm Reduction Project Boundary',
                   'HSOC Zones as of 2018-06-05',
                   'Invest In Neighborhoods (IIN) Areas',
                   'Current Supervisor Districts',
                   'Current Police Districts']

crime_new_df = crime_df.drop(columns=columns_to_drop)

print("\nNew DataFrame:")
print("-------------------")
print(crime_new_df.dtypes)
# Out:
# Original DataFrame:
# -------------------
# Incident Datetime                                        object
# Incident Date                                            object
# Incident Time                                            object
# Incident Year                                             int64
# Incident Day of Week                                     object
# Report Datetime                                          object
# Row ID                                                    int64
# Incident ID                                               int64
# Incident Number                                           int64
# CAD Number                                              float64
# Report Type Code                                         object
# Report Type Description                                  object
# Filed Online                                             object
# Incident Code                                             int64
# Incident Category                                        object
# Incident Subcategory                                     object
# Incident Description                                     object
# Resolution                                               object
# Intersection                                             object
# CNN                                                     float64
# Police District                                          object
# Analysis Neighborhood                                    object
# Supervisor District                                     float64
# Supervisor District 2012                                float64
# Latitude                                                float64
# Longitude                                               float64
# Point                                                    object
# Neighborhoods                                           float64
# ESNCAG - Boundary File                                  float64
# Central Market/Tenderloin Boundary Polygon - Updated    float64
# Civic Center Harm Reduction Project Boundary            float64
# HSOC Zones as of 2018-06-05                             float64
# Invest In Neighborhoods (IIN) Areas                     float64
# Current Supervisor Districts                            float64
# Current Police Districts                                float64
# dtype: object
#
# New DataFrame:
# -------------------
# Incident Datetime         object
# Incident Date             object
# Incident Time             object
# Incident Year              int64
# Incident Day of Week      object
# Report Datetime           object
# Incident ID                int64
# Incident Number            int64
# Incident Code              int64
# Incident Category         object
# Incident Subcategory      object
# Incident Description      object
# Resolution                object
# Intersection              object
# Police District           object
# Analysis Neighborhood     object
# Latitude                 float64
# Longitude                float64
# Point                     object
# dtype: object

# %%
# View new DataFrame
crime_new_df.head(5)
# Out:
#         Incident Datetime Incident Date Incident Time  Incident Year  \
# 0  2023/03/13 11:41:00 PM    2023/03/13         23:41           2023
# 1  2023/03/01 05:02:00 AM    2023/03/01         05:02           2023
# 2  2023/03/13 01:16:00 PM    2023/03/13         13:16           2023
# 3  2023/03/13 10:59:00 AM    2023/03/13         10:59           2023
# 4  2023/03/14 06:44:00 PM    2023/03/14         18:44           2023
#
#   Incident Day of Week         Report Datetime  Incident ID  Incident Number  \
# 0               Monday  2023/03/13 11:41:00 PM      1253736        230167874
# 1            Wednesday  2023/03/11 03:40:00 PM      1253795        236046151
# 2               Monday  2023/03/13 01:17:00 PM      1253571        220343896
# 3               Monday  2023/03/13 11:00:00 AM      1253551        230174885
# 4              Tuesday  2023/03/14 06:45:00 PM      1254024        230176728
#
#    Incident Code  Incident Category   Incident Subcategory  \
# 0           7041  Recovered Vehicle      Recovered Vehicle
# 1           6374      Larceny Theft  Larceny Theft - Other
# 2           7041  Recovered Vehicle      Recovered Vehicle
# 3           7041  Recovered Vehicle      Recovered Vehicle
# 4           7041  Recovered Vehicle      Recovered Vehicle
#
#            Incident Description      Resolution Intersection Police District  \
# 0      Vehicle, Recovered, Auto  Open or Active          NaN       Out of SF
# 1  Theft, Other Property, >$950  Open or Active          NaN         Mission
# 2      Vehicle, Recovered, Auto  Open or Active          NaN       Out of SF
# 3      Vehicle, Recovered, Auto  Open or Active          NaN       Out of SF
# 4      Vehicle, Recovered, Auto  Open or Active          NaN       Out of SF
#
#   Analysis Neighborhood  Latitude  Longitude Point
# 0                   NaN       NaN        NaN   NaN
# 1                   NaN       NaN        NaN   NaN
# 2                   NaN       NaN        NaN   NaN
# 3                   NaN       NaN        NaN   NaN
# 4                   NaN       NaN        NaN   NaN

# %%
# Remove rows with null values for latitude, longitude, and analysis neighborhood
crime_new_df = crime_new_df.dropna(subset=['Longitude', 'Latitude', 'Analysis Neighborhood'])
crime_new_df.head(5)
# Out:
#          Incident Datetime Incident Date Incident Time  Incident Year  \
# 9   2023/03/11 02:00:00 PM    2023/03/11         14:00           2023
# 11  2022/06/27 12:00:00 PM    2022/06/27         12:00           2022
# 13  2023/03/16 05:30:00 PM    2023/03/16         17:30           2023
# 33  2023/03/21 03:50:00 PM    2023/03/21         15:50           2023
# 61  2021/08/22 09:40:00 AM    2021/08/22         09:40           2021
#
#    Incident Day of Week         Report Datetime  Incident ID  Incident Number  \
# 9              Saturday  2023/03/15 11:21:00 AM      1254318        230182844
# 11               Monday  2023/03/15 05:20:00 PM      1254393        230184129
# 13             Thursday  2023/03/16 06:02:00 PM      1254826        230187101
# 33              Tuesday  2023/03/21 04:01:00 PM      1256563        230199764
# 61               Sunday  2021/08/22 09:40:00 AM      1062676        210537297
#
#     Incident Code Incident Category Incident Subcategory Incident Description  \
# 9            4134           Assault       Simple Assault              Battery
# 11          71000     Lost Property        Lost Property        Lost Property
# 13           4134           Assault       Simple Assault              Battery
# 33          51040      Non-Criminal         Non-Criminal           Aided Case
# 61          62071           Warrant                Other     Probation Search
#
#         Resolution             Intersection Police District  \
# 9   Open or Active    STANYAN ST \ HAYES ST            Park
# 11  Open or Active     GEARY ST \ POWELL ST         Central
# 13  Open or Active     18TH ST \ DE HARO ST         Bayview
# 33  Open or Active      POST ST \ LARKIN ST        Northern
# 61  Open or Active  LAGUNA ST \ PACIFIC AVE        Northern
#
#              Analysis Neighborhood   Latitude   Longitude  \
# 9                 Golden Gate Park  37.772895 -122.454285
# 11  Financial District/South Beach  37.787359 -122.408227
# 13                    Potrero Hill  37.762290 -122.401324
# 33                      Tenderloin  37.787038 -122.418271
# 61                 Pacific Heights  37.793977 -122.429804
#
#                                              Point
# 9   POINT (-122.45428511766733 37.772895177200766)
# 11   POINT (-122.40822672700406 37.78735926098589)
# 13   POINT (-122.40132418490647 37.76228996810526)
# 33  POINT (-122.41827098126804 37.787037946181535)
# 61   POINT (-122.42980398313114 37.79397724418211)

# %%
# List of categories to remove
categories_to_remove = [
    'Non-Criminal', 'Case-Closure', 'Vehicle-Misplaced',
    'Suicide', 'Civil Sidewalks', 'Traffic Collision', 'Liquor Laws'
]

# Remove rows where 'Incident Category' is in the list of categories to remove
crime_new_df = crime_new_df[~crime_new_df['Incident Category'].isin(categories_to_remove)]

# Display the DataFrame to confirm the changes
crime_new_df.head(5)
# Out:
#          Incident Datetime Incident Date Incident Time  Incident Year  \
# 9   2023/03/11 02:00:00 PM    2023/03/11         14:00           2023
# 11  2022/06/27 12:00:00 PM    2022/06/27         12:00           2022
# 13  2023/03/16 05:30:00 PM    2023/03/16         17:30           2023
# 61  2021/08/22 09:40:00 AM    2021/08/22         09:40           2021
# 87  2022/07/02 10:53:00 PM    2022/07/02         22:53           2022
#
#    Incident Day of Week         Report Datetime  Incident ID  Incident Number  \
# 9              Saturday  2023/03/15 11:21:00 AM      1254318        230182844
# 11               Monday  2023/03/15 05:20:00 PM      1254393        230184129
# 13             Thursday  2023/03/16 06:02:00 PM      1254826        230187101
# 61               Sunday  2021/08/22 09:40:00 AM      1062676        210537297
# 87             Saturday  2022/07/02 11:00:00 PM      1166803        220435590
#
#     Incident Code Incident Category Incident Subcategory Incident Description  \
# 9            4134           Assault       Simple Assault              Battery
# 11          71000     Lost Property        Lost Property        Lost Property
# 13           4134           Assault       Simple Assault              Battery
# 61          62071           Warrant                Other     Probation Search
# 87           4134           Assault       Simple Assault              Battery
#
#         Resolution             Intersection Police District  \
# 9   Open or Active    STANYAN ST \ HAYES ST            Park
# 11  Open or Active     GEARY ST \ POWELL ST         Central
# 13  Open or Active     18TH ST \ DE HARO ST         Bayview
# 61  Open or Active  LAGUNA ST \ PACIFIC AVE        Northern
# 87  Open or Active    GILMAN AVE \ HAWES ST         Bayview
#
#              Analysis Neighborhood   Latitude   Longitude  \
# 9                 Golden Gate Park  37.772895 -122.454285
# 11  Financial District/South Beach  37.787359 -122.408227
# 13                    Potrero Hill  37.762290 -122.401324
# 61                 Pacific Heights  37.793977 -122.429804
# 87           Bayview Hunters Point  37.719298 -122.390020
#
#                                              Point
# 9   POINT (-122.45428511766733 37.772895177200766)
# 11   POINT (-122.40822672700406 37.78735926098589)
# 13   POINT (-122.40132418490647 37.76228996810526)
# 61   POINT (-122.42980398313114 37.79397724418211)
# 87  POINT (-122.39001968579463 37.719298464887245)

# %%
# Find the different incident types, count each occurance in dataset
unique_counts = crime_new_df["Incident Category"].value_counts()
unique_incidents_df = pd.DataFrame(unique_counts.items(), columns=["Unique_Values", "Counts"])

# Display the categories and their counts
unique_incidents_df
# Out:
#                                    Unique_Values  Counts
# 0                                  Larceny Theft  232067
# 1                            Other Miscellaneous   57580
# 2                             Malicious Mischief   55053
# 3                                        Assault   52032
# 4                                       Burglary   46693
# 5                            Motor Vehicle Theft   45541
# 6                                          Fraud   27057
# 7                              Recovered Vehicle   24489
# 8                                        Warrant   24219
# 9                                   Drug Offense   21259
# 10                                 Lost Property   19894
# 11                                       Robbery   18961
# 12                                Missing Person   18310
# 13                                Suspicious Occ   17451
# 14                            Disorderly Conduct   14564
# 15      Offences Against The Family And Children   11177
# 16                   Miscellaneous Investigation    9566
# 17                      Traffic Violation Arrest    7944
# 18                                         Other    7136
# 19                                Other Offenses    6229
# 20                               Weapons Offense    5897
# 21                          Weapons Carrying Etc    4540
# 22                               Stolen Property    4088
# 23                                  Case Closure    3193
# 24                    Forgery And Counterfeiting    2916
# 25                               Courtesy Report    2505
# 26                                         Arson    2459
# 27                                     Vandalism    1944
# 28                                   Fire Report    1268
# 29                                  Embezzlement    1065
# 30                                   Sex Offense     898
# 31                                  Prostitution     860
# 32                             Vehicle Impounded     603
# 33                             Vehicle Misplaced     361
# 34                                Drug Violation     273
# 35                                          Rape     209
# 36                                      Homicide     147
# 37                                    Suspicious     115
# 38    Human Trafficking (A), Commercial Sex Acts     114
# 39                          Motor Vehicle Theft?      84
# 40                                      Gambling      40
# 41        Human Trafficking, Commercial Sex Acts      23
# 42                               Weapons Offence      23
# 43  Human Trafficking (B), Involuntary Servitude       2

# %%
# Count the total incidents for each 'Analysis Neighborhood'
neighborhood_incident_counts = crime_new_df['Analysis Neighborhood'].value_counts()

# Display the counts
print(neighborhood_incident_counts)
# Out:
# Analysis Neighborhood
# Mission                           80468
# Tenderloin                        77583
# South of Market                   61165
# Financial District/South Beach    59672
# Bayview Hunters Point             50684
# North Beach                       25462
# Western Addition                  24784
# Sunset/Parkside                   22313
# Nob Hill                          21744
# Castro/Upper Market               21305
# Marina                            21176
# Hayes Valley                      20987
# Russian Hill                      18324
# Outer Richmond                    17162
# West of Twin Peaks                15471
# Bernal Heights                    14522
# Pacific Heights                   13647
# Chinatown                         13542
# Mission Bay                       13126
# Excelsior                         12985
# Potrero Hill                      12964
# Haight Ashbury                    11687
# Outer Mission                     11137
# Lakeshore                         10046
# Inner Richmond                     9902
# Inner Sunset                       9900
# Lone Mountain/USF                  9368
# Portola                            9025
# Noe Valley                         8480
# Visitacion Valley                  8418
# Oceanview/Merced/Ingleside         8146
# Japantown                          7992
# Golden Gate Park                   7813
# Presidio Heights                   5022
# Glen Park                          4291
# Twin Peaks                         3818
# Treasure Island                    2700
# Presidio                           1560
# Lincoln Park                       1272
# Seacliff                           1011
# McLaren Park                        952
# Name: count, dtype: int64

# %%
# Bar chart to show least safe neighborhoods SF

# Plot the bar chart
plt.figure(figsize=(12, 8))
neighborhood_incident_counts.plot(kind='bar')
plt.title('Total Incidents by Analysis Neighborhood')
plt.xlabel('Analysis Neighborhood')
plt.ylabel('Total Incidents')
plt.xticks(rotation=90) 
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Pie chart to show the top 10 neighborhoods with the most incidents
top_neighborhood_crime_counts = crime_new_df['Analysis Neighborhood'].value_counts().nlargest(10)

# Plot the pie chart
plt.figure(figsize=(10, 8))
top_neighborhood_crime_counts.plot(kind='pie', autopct='%1.1f%%')
plt.title('Percentage of Incidents by Analysis Neighborhood')
plt.ylabel('')
plt.tight_layout()

# Show the plot
plt.show()

# %%
# List of neighborhoods with the most amount of incidents, convert to DF
least_safe_neighborhoods_df = pd.DataFrame(top_neighborhood_crime_counts)

print("Neighborhoods with the most amount of incidents:")
least_safe_neighborhoods_df.head()
# Out:
# Neighborhoods with the most amount of incidents:
#                                 count
# Analysis Neighborhood
# Mission                         80468
# Tenderloin                      77583
# South of Market                 61165
# Financial District/South Beach  59672
# Bayview Hunters Point           50684

# %%
# Find the safest neighborhoods in San Francisco
neighborhoods_least_incidents = neighborhood_incident_counts.nsmallest(10) 

safe_neighborhoods_df = pd.DataFrame(neighborhoods_least_incidents)

# Display the neighborhoods with the least amount of incidents
print("Neighborhoods with the least amount of incidents:")
safe_neighborhoods_df.head()
# Out:
# Neighborhoods with the least amount of incidents:
#                        count
# Analysis Neighborhood
# McLaren Park             952
# Seacliff                1011
# Lincoln Park            1272
# Presidio                1560
# Treasure Island         2700

# %%
# Create new DataFrames for yearly data analysis

# List of years to access from df
years = [2019, 2020, 2021, 2022, 2023, 2024]

# Create dictionary to hold DataFrames for each year
crime_df_by_year = {}

# Create a new DataFrame for each year and store in the dictionary
for year in years:
    crime_df_by_year[year] = crime_new_df[crime_new_df['Incident Year'] == year]

# Display the DataFrame for 2024 to confirm
crime_df_2024 = crime_df_by_year[2024]
crime_df_2024.head(5)
# Out:
#            Incident Datetime Incident Date Incident Time  Incident Year  \
# 1786  2024/05/02 01:00:00 AM    2024/05/02         01:00           2024
# 1787  2024/03/28 12:00:00 AM    2024/03/28         00:00           2024
# 1788  2024/04/27 10:45:00 AM    2024/04/27         10:45           2024
# 1790  2024/01/19 10:00:00 AM    2024/01/19         10:00           2024
# 1791  2024/05/02 10:30:00 AM    2024/05/02         10:30           2024
#
#      Incident Day of Week         Report Datetime  Incident ID  \
# 1786             Thursday  2024/05/02 03:53:00 AM      1387024
# 1787             Thursday  2024/05/02 10:49:00 AM      1387092
# 1788             Saturday  2024/04/27 11:27:00 AM      1387047
# 1790               Friday  2024/05/02 04:55:00 PM      1387191
# 1791             Thursday  2024/05/02 01:29:00 PM      1387177
#
#       Incident Number  Incident Code    Incident Category  \
# 1786        240275752          27195  Other Miscellaneous
# 1787        240276205          74000       Missing Person
# 1788        246057370          28150   Malicious Mischief
# 1790        240277156           9250                Fraud
# 1791        240276675          61030                Other
#
#      Incident Subcategory                       Incident Description  \
# 1786             Trespass                                Trespassing
# 1787        Missing Adult                              Missing Adult
# 1788            Vandalism  Malicious Mischief, Vandalism to Property
# 1790                Fraud    Fraudulent Use Of Automated Teller Card
# 1791                Other                Death Report, Cause Unknown
#
#           Resolution                          Intersection Police District  \
# 1786  Open or Active                 DELTA ST \ TUCKER AVE       Ingleside
# 1787  Open or Active                   POST ST \ TAYLOR ST         Central
# 1788  Open or Active  CORBETT AVE \ CUESTA CT \ PORTOLA DR            Park
# 1790  Open or Active                GOUGH ST \ PACIFIC AVE        Northern
# 1791  Open or Active                JONES ST \ OFARRELL ST      Tenderloin
#
#      Analysis Neighborhood   Latitude   Longitude  \
# 1786          McLaren Park  37.716507 -122.408020
# 1787              Nob Hill  37.787872 -122.411697
# 1788            Twin Peaks  37.750458 -122.443970
# 1790       Pacific Heights  37.794399 -122.426514
# 1791            Tenderloin  37.785789 -122.412971
#
#                                                Point
# 1786   POINT (-122.40802001953125 37.71650695800781)
# 1787  POINT (-122.41169738769531 37.787872314453125)
# 1788   POINT (-122.4439697265625 37.750457763671875)
# 1790     POINT (-122.426513671875 37.79439926147461)
# 1791  POINT (-122.41297149658203 37.785789489746094)

# %%
# See neighborhood data for 2024
neighborhood_crime_counts_2024 = crime_df_2024['Analysis Neighborhood'].value_counts()

# Display the counts
print(neighborhood_crime_counts_2024)
# Out:
# Analysis Neighborhood
# Tenderloin                        4780
# Mission                           3786
# South of Market                   2869
# Bayview Hunters Point             2349
# Financial District/South Beach    1920
# Western Addition                  1318
# Sunset/Parkside                   1180
# Nob Hill                          1016
# North Beach                        909
# Bernal Heights                     857
# Castro/Upper Market                830
# Marina                             811
# Hayes Valley                       798
# West of Twin Peaks                 796
# Excelsior                          694
# Outer Richmond                     673
# Chinatown                          624
# Outer Mission                      622
# Russian Hill                       611
# Pacific Heights                    592
# Potrero Hill                       565
# Noe Valley                         504
# Lakeshore                          494
# Inner Richmond                     462
# Lone Mountain/USF                  454
# Haight Ashbury                     451
# Inner Sunset                       431
# Portola                            421
# Mission Bay                        417
# Visitacion Valley                  381
# Oceanview/Merced/Ingleside         372
# Golden Gate Park                   349
# Japantown                          253
# Presidio Heights                   233
# Glen Park                          214
# Twin Peaks                         162
# Treasure Island                    126
# Lincoln Park                        62
# McLaren Park                        54
# Seacliff                            36
# Presidio                            35
# Name: count, dtype: int64
